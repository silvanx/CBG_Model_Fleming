# %%
from pathlib import Path
import utils as u

# %%
dirname = 'Controller_Simulations/Freq/standard_PID_Controller/Kp=19.300000, Ti=0.200000, Td=0.000000'
parameter = 'frequency'
plot_start_t = 9000
plot_end_t = 11000
steady_state_time = 6000
sim_time = 38000.01

# %%
dir = Path(dirname)
time, dbs = u.load_DBS_output(dir)
lfp_time, lfp = u.load_STN_LFP(dir, steady_state_time, sim_time)
controller_t, controller_p = u.load_controller_data(dir, parameter)
u.plot_controller_result(plot_start_t, plot_end_t, parameter,
                         time, dbs, controller_t, controller_p,
                         lfp_time, lfp)

# %%
dirname = 'Controller_Simulations/Amp/standard_PID_Controller/Kp=0.230000, Ti=0.200000, Td=0.000000'
parameter = 'amplitude'

# %%
dir = Path(dirname)
time, dbs = u.load_DBS_output(dir)
lfp_time, lfp = u.load_STN_LFP(dir, steady_state_time, sim_time)
controller_t, controller_p = u.load_controller_data(dir, parameter)
u.plot_controller_result(plot_start_t, plot_end_t, parameter,
                         time, dbs, controller_t, controller_p,
                         lfp_time, lfp)
