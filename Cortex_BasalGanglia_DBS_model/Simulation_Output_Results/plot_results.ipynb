# %%
from pathlib import Path
import plot_utils as u

# %%
plot_start_t = 9000
plot_end_t = 12000
steady_state_time = 6000
sim_time = 18000.01

# %%
u.plot_mse_dir('Controller_Simulations/Amp/standard_PID_Controller')

# %%
u.plot_mse_dir('Controller_Simulations/Zero')

# %%
parameter = 'amplitude'
dirname = ['ZeroController-20220919144722',
           'ZeroController-20220919144758']

u.load_and_plot(['Controller_Simulations/Zero/' + d for d in dirname], parameter, steady_state_time, sim_time, plot_start_t, plot_end_t)

# %%
parameter = 'amplitude'
dirname = ['Kp=0.230000, Ti=0.200000, Td=0.000000-20220919013755',
           'Kp=0.230000, Ti=0.200000, Td=0.000000-20220919014120']

u.load_and_plot(['Controller_Simulations/Amp/standard_PID_Controller/' + d for d in dirname], parameter, steady_state_time, sim_time, plot_start_t, plot_end_t)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\cic\wrk\20220530_John_model\Cortex_BasalGanglia_DBS_model\Simulation_Output_Results\plot_results.ipynb Komórka 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/cic/wrk/20220530_John_model/Cortex_BasalGanglia_DBS_model/Simulation_Output_Results/plot_results.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> parameter = 'amplitude'
#       <a href='vscode-notebook-cell:/c%3A/cic/wrk/20220530_John_model/Cortex_BasalGanglia_DBS_model/Simulation_Output_Results/plot_results.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> dirname = ['Kp=0.230000, Ti=0.200000, Td=0.000000-20220919013755',
#       <a href='vscode-notebook-cell:/c%3A/cic/wrk/20220530_John_model/Cortex_BasalGanglia_DBS_model/Simulation_Output_Results/plot_results.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>            'Kp=0.230000, Ti=0.200000, Td=0.000000-20220919014120']
# ----> <a href='vscode-notebook-cell:/c%3A/cic/wrk/20220530_John_model/Cortex_BasalGanglia_DBS_model/Simulation_Output_Results/plot_results.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> u.load_and_plot(['Controller_Simulations/Amp/standard_PID_Controller/' + d for d in dirname], parameter, steady_state_time, sim_time, plot_start_t, plot_end_t)
#
# File c:\cic\wrk\20220530_John_model\Cortex_BasalGanglia_DBS_model\Simulation_Output_Results\plot_utils.py:108, in load_and_plot(dirname, parameter, steady_state_time, sim_time, plot_start_t, plot_end_t)
#     105 lfp_time, lfp = load_stn_lfp(directory, steady_state_time, sim_time)
#     106 controller_t, controller_p, controller_b =\
#     107     load_controller_data(directory, parameter)
# --> 108 axs = plot_controller_result(plot_start_t, plot_end_t, parameter, time,
#     109                              dbs, controller_t, controller_p,
#     110                              controller_b, lfp_time, lfp, axs)
#
# File c:\cic\wrk\20220530_John_model\Cortex_BasalGanglia_DBS_model\Simulation_Output_Results\plot_utils.py:67, in plot_controller_result(plot_start_t, plot_end_t, parameter, time, dbs, controller_t, controller_p, controller_b, lfp_time, lfp, axs)
#      65     fig, axs = plt.subplots(4, 1, figsize=(15, 8))
#      66 s = time_to_sample(time['signal'], plot_start_t)
# ---> 67 e = time_to_sample(time['signal'], plot_end_t) - 1
#      68 axs[0].plot(time['signal'][s:e], dbs['signal'][s: e])
#      69 axs[0].set_xlabel('Time [%s]' % time['signal_units'][0])
#
# File c:\cic\wrk\20220530_John_model\Cortex_BasalGanglia_DBS_model\Simulation_Output_Results\plot_utils.py:56, in time_to_sample(tt, t)
#      53 def time_to_sample(tt: np.ndarray, t: float) -> int:
#      54     '''Finds the first index in a time array where time is greater than or
#      55     equal to t.'''
# ---> 56     return np.where(tt >= t)[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plot_start_t = 9000
plot_end_t = 12000
steady_state_time = 6000
sim_time = 14000.01

# %%
parameter = 'frequency'
dirname =['Kp=19.300000, Ti=0.200000, Td=0.000000-20220830153118',
          'Kp=19.300000, Ti=0.200000, Td=0.000000-20220830152231']
u.load_and_plot(['Controller_Simulations/Freq/standard_PID_Controller/' + d for d in dirname], parameter, steady_state_time, sim_time, plot_start_t, plot_end_t)
